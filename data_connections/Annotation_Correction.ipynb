# %%
# %matplotlib widget
import matplotlib.pyplot as plt
from pandas_statistics import file_path_loader

# %%
path="/home/davidchaparro/Repos/Dataset_Compilation_and_Statistics/data/LMNT02Sat-2024-12-20"
local = file_path_loader(path)
local.correct_annotations()
# Out:
# ...
#  35%|███▌      | 103/291 [48:36<1:28:43, 28.32s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 path="/home/davidchaparro/Repos/Dataset_Compilation_and_Statistics/data/LMNT02Sat-2024-12-20"
#       2 local = file_path_loader(path)
# ----> 3 local.correct_annotations()
#
# File ~/Repos/Dataset_Compilation_and_Statistics/data_connections/pandas_statistics.py:187, in file_path_loader.correct_annotations(self)
#     184 new_bbox = find_new_centroid(image, original_bbox)
#     185 plot_single_annotation(image, original_bbox, new_bbox, title)
# --> 187 current_input = input("Keep New Annotation? [Enter any letter for yes]: ")
#     188 plt.clf()   # Clears the current figure
#     189 plt.cla()   # Clears the current axes (optional)
#
# ...
