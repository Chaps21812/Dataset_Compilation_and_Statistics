# %%
# %matplotlib widget
import matplotlib.pyplot as plt
from pandas_statistics import file_path_loader

path="/mnt/c/Users/david.chaparro/Documents/Repos/Dataset_Statistics/data/LMNT01Satellite-2024-07-08"
local = file_path_loader(path)
local.correct_annotations(apply_changes=False)
# Out:
# ...
#  17%|█▋        | 53/311 [17:41<1:26:07, 20.03s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 7
#       5 path="/mnt/c/Users/david.chaparro/Documents/Repos/Dataset_Statistics/data/LMNT01Satellite-2024-07-08"
#       6 local = file_path_loader(path)
# ----> 7 local.correct_annotations(apply_changes=False)
#
# File /mnt/c/Users/david.chaparro/Documents/Repos/Dataset_Statistics/data_connections/pandas_statistics.py:200, in file_path_loader.correct_annotations(self, apply_changes)
#     197 new_bbox = find_centroid_COM(image, original_bbox)
#     198 plot_single_annotation(image, original_bbox, new_bbox, title)
# --> 200 current_input = input("Keep New Annotation? [Enter any letter for yes]: ")
#     201 plt.clf()   # Clears the current figure
#     202 plt.cla()   # Clears the current axes (optional)
#
# ...
