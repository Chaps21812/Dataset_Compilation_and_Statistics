# %%
from src.s3client import S3Client

ABQ01_PATH = "third-party-data/PDS-ABQ-01/Satellite/Annotations/"
KWAJ01_PATH = "third-party-data/PDS-KWAJ01/Satellite/Annotations/"
LMNT01_PATH= "third-party-data/PDS-LMNT01/Satellite/Annotations/"
LMNT02_PATH = "third-party-data/PDS-LMNT02/Satellite/Annotations/"
RME01_PATH ="third-party-data/PDS-RME01/Satellite/Annotations/"
RME04_PATH ="third-party-data/PDS-RME04/Satellite/Annotations/"
RME03_PATH = "third-party-data/PDS-RME03/Satellite/Annotations/PDS-RME03/"

# %%
S3Client(ABQ01_PATH).download_annotation_dates
# Out:
# Loading file locations: 0it [00:05, ?it/s]
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 S3Client(ABQ01_PATH).download_annotation_dates
#
# File /data/Dataset_Compilation_and_Statistics/data_connections/src/s3client.py:50, in S3Client.__init__(self, directory)
#      47 self.annotation_dates = Counter()
#      49 self.errors = 0
# ---> 50 self.get_data(self.directory)
#
# File /data/Dataset_Compilation_and_Statistics/data_connections/src/s3client.py:65, in S3Client.get_data(self, directory)
#      62 paginator = self.client.get_paginator('list_objects_v2')
#      63 page_iterator = paginator.paginate(Bucket=self.bucket, Prefix=directory)
# ---> 65 for i, page in enumerate(tqdm(page_iterator, desc="Loading file locations")):
#      66     if "Contents" in page:
#      67         for key in page[ "Contents" ]:
#
# File ~/miniconda3/envs/DatasetStatistics/lib/python3.12/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File ~/miniconda3/envs/DatasetStatistics/lib/python3.12/site-packages/botocore/paginate.py:272, in PageIterator.__iter__(self)
#     270 self._inject_starting_params(current_kwargs)
#     271 while True:
# --> 272     response = self._make_request(current_kwargs)
#     273     parsed = self._extract_parsed_response(response)
#     274     if first_request:
#     275         # The first request is handled differently.  We could
#     276         # possibly have a resume/starting token that tells us where
#     277         # to index into the retrieved page.
#
# File ~/miniconda3/envs/DatasetStatistics/lib/python3.12/site-packages/botocore/context.py:123, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     121 if hook:
#     122     hook()
# --> 123 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/DatasetStatistics/lib/python3.12/site-packages/botocore/paginate.py:361, in PageIterator._make_request(self, current_kwargs)
#     359 @with_current_context(partial(register_feature_id, 'PAGINATOR'))
#     360 def _make_request(self, current_kwargs):
# --> 361     return self._method(**current_kwargs)
#
# File ~/miniconda3/envs/DatasetStatistics/lib/python3.12/site-packages/botocore/client.py:570, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     566     raise TypeError(
#     567         f"{py_operation_name}() only accepts keyword arguments."
#     568     )
#     569 # The "self" in this scope is referring to the BaseClient.
# --> 570 return self._make_api_call(operation_name, kwargs)
#
# File ~/miniconda3/envs/DatasetStatistics/lib/python3.12/site-packages/botocore/context.py:123, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     121 if hook:
#     122     hook()
# --> 123 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/DatasetStatistics/lib/python3.12/site-packages/botocore/client.py:1031, in BaseClient._make_api_call(self, operation_name, api_params)
#    1027     error_code = error_info.get("QueryErrorCode") or error_info.get(
#    1028         "Code"
#    1029     )
#    1030     error_class = self.exceptions.from_code(error_code)
# -> 1031     raise error_class(parsed_response, operation_name)
#    1032 else:
#    1033     return parsed_response
#
# ClientError: An error occurred (InvalidToken) when calling the ListObjectsV2 operation: The provided token is malformed or otherwise invalid.

# %%
S3Client("silt-data/third-party-data/PDS-KWAJ01/Satellite/Annotations")
# Out:
# Refreshed session token; expires: 2025-11-28 11:28:36+00:00
# 2025-11-28 11:28:36+00:00
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 S3Client("silt-data/third-party-data/PDS-KWAJ01/Satellite/Annotations")
#
# File /data/Dataset_Compilation_and_Statistics/data_connections/src/s3client.py:35, in S3Client.__init__(self, directory)
#      25 """
#      26 Scans a directory on the S3 silt bucket and has functions to download and organize FITS files. Needs a key from the AWS AI_Autonomy Dev cloud to work correctly, and a refreshed UDL key to download stuff.
#      27
#    (...)     32     S3Client
#      33 """
#      34 self.client_generator = RefreshableSession(ACCESS_KEY, SECRET_KEY)
# ---> 35 self.client = self.client_generator.client("s3")
#      36 self.bucket = "silt-annotations"
#      37 self.directory = directory
