# %%
from src.raw_datset import raw_dataset
from src.coco_tools import COCODataset
from src.preprocess_functions import raw_file, iqr_log, raw_file_16bit, iqr_log_16bit
from src.s3client import S3Client
import os

if __name__ == "__main__":
    
    from src.raw_datset import raw_dataset
    from src.coco_tools import COCODataset
    import os
    telescope_directory = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/RME04-2025Data"

    # telescope_basename = os.path.basename(telescope_directory)
    # for date_folder in os.listdir(telescope_directory):
    subfolder = telescope_directory
    if os.path.isdir(subfolder):
        dataset = raw_dataset(subfolder)
        coco_dataset = COCODataset(subfolder)
        coco_dataset.build_annotations()
        coco_dataset.generate_TTV_split(train_ratio=0.80,val_ratio=0.10,test_ratio=0.10)
# Out:
# Deleted folder: /data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/RME04-2025Data/annotations
# Deleted folder: /data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/RME04-2025Data/multiframe_annotations
# Building COCO Annotations: 100%|██████████| 22517/22517 [13:40<00:00, 27.44it/s]

# %%
import multiprocessing as mp
import sys
from src.raw_datset import raw_dataset
from src.coco_tools import COCODataset, CalsatDataset
import shutil
import os
from src.preprocess_functions import raw_file_16bit, raw_file,iqr_log,iqr_log_16bit
from src.multiprocessing import SimpleFileLogger

from src.raw_datset import raw_dataset
from src.coco_tools import COCODataset
import os


TELESCOPE_B = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/RME01-2025-Annotations"

paths_A = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/RME01-2025-Annotations/2025-10-21"
paths_B = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/RME01-2025-Annotations/2025-10-23"
paths_C = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/RME01-2025-Annotations/2025-10-24"
paths_D = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/RME01-2025-Annotations/2025-10-25"
paths_E = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/RME01-2025-Annotations/2025-10-27"
paths_F = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/RME01-2025-Annotations/2025-10-28"
paths_G = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/RME01-2025-Annotations/2025-10-29"



print(f"PRocessing Dataset {os.path.basename(TELESCOPE_B)}...(PID={os.getpid()})")
for date_folder in [paths_A,paths_B,paths_C,paths_D,paths_E,paths_F,paths_G]:
    if os.path.isdir(date_folder):
        coco_dataset = COCODataset(date_folder)
        coco_dataset.move_fits_to_train_test_split(raw_file_16bit)
print("Complete, have a nice day, say an affirmation, eat some cheese.")
# Out:
# PRocessing Dataset RME01-2025-Annotations...(PID=2547223)
# ...
# Copying images: 100%|██████████| 12/12 [00:24<00:00,  2.08s/it]
# Copying images: 0it [00:00, ?it/s]
# Copying images: 0it [00:00, ?it/s]
# Copying images:   9%|▊         | 28/326 [00:58<10:22,  2.09s/it]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/miniconda3/envs/DatasetStatistics/lib/python3.12/site-packages/PIL/ImageFile.py:643, in _save(im, fp, tile, bufsize)
#     642 try:
# --> 643     fh = fp.fileno()
#     644     fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 31
#      29     if os.path.isdir(date_folder):
#      30         coco_dataset = COCODataset(date_folder)
# ...
