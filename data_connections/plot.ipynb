# %%
from pandas_statistics import file_path_loader
from plots import *

# %%
#Enter the Directory of data you wish to produce statistics plots for
file_path_loader = file_path_loader("/mnt/c/Users/david.chaparro/Documents/Repos/Dataset-Statistics/data/RME03Star")
plots_save_path = "/mnt/c/Users/david.chaparro/Documents/Repos/Dataset-Statistics/data/RME03Star/plots/"
print(len(file_path_loader))


data_statistics = file_path_loader.statistics_file
# Out:
# 2502

# %%
#file_path_loader.recalculate_statistics()
# Out:
# New database created at /mnt/c/Users/david.chaparro/Documents/Repos/Dataset-Statistics/data/RME03Star/RME03Star_Statistics.pkl
# Recalculating Statistics: 100%|██████████| 3202/3202 [18:18<00:00,  2.91it/s]

# %%
for col_name, col_data in data_statistics.sample_attributes.items():
    column_type = detect_column_type(col_data)
    print(column_type)
    if column_type == "categorical":
        plot_categorical_column(col_data, filepath=plots_save_path, dpi=500)
    elif column_type == "numerical":
        plot_numerical_column(col_data, filepath=plots_save_path, dpi=500)
    elif column_type == "time":
        plot_time_column(col_data, filepath=plots_save_path, dpi=500)
# Out:
# categorical
# categorical
# /mnt/c/Users/david.chaparro/Documents/Repos/Dataset-Statistics/data_connections/plots.py:80: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# /mnt/c/Users/david.chaparro/Documents/Repos/Dataset-Statistics/data_connections/plots.py:90: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# categorical
# /mnt/c/Users/david.chaparro/Documents/Repos/Dataset-Statistics/data_connections/plots.py:80: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# /mnt/c/Users/david.chaparro/Documents/Repos/Dataset-Statistics/data_connections/plots.py:90: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# categorical
# numerical
# categorical
# numerical
# numerical
# categorical
# time
# numerical
# categorical

# %%
for col_name, col_data in data_statistics.annotation_attributes.items():
    column_type = detect_column_type(col_data)
    if column_type == "categorical":
        plot_categorical_column(col_data, filepath=plots_save_path, dpi=500)
    elif column_type == "numerical":
        plot_numerical_column(col_data, filepath=plots_save_path, dpi=500)
# Out:
# /mnt/c/Users/david.chaparro/Documents/Repos/Dataset-Statistics/data_connections/plots.py:80: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# /mnt/c/Users/david.chaparro/Documents/Repos/Dataset-Statistics/data_connections/plots.py:90: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# /mnt/c/Users/david.chaparro/Documents/Repos/Dataset-Statistics/data_connections/plots.py:80: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# /mnt/c/Users/david.chaparro/Documents/Repos/Dataset-Statistics/data_connections/plots.py:90: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
x_locations=data_statistics.annotation_attributes["x_center"]
y_locations=data_statistics.annotation_attributes["y_center"]
plot_scatter(x_locations, y_locations, alpha=.05, filepath=plots_save_path, dpi=500)

# %%
plot_lines(data_statistics.annotation_attributes["x1"], data_statistics.annotation_attributes["y1"],
           data_statistics.annotation_attributes["x2"], data_statistics.annotation_attributes["y2"],
           filepath=plots_save_path, dpi=500, alpha=.10)

# %%
plt.hist(data_statistics.sample_attributes["num_objects"], bins=100)
plt.show()
print(len(data_statistics.sample_attributes[data_statistics.sample_attributes["num_objects"]==0]))
# Out:
# 192
