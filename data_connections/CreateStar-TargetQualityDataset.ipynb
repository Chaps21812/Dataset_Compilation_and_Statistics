# %% [markdown]
# # Create Star Quality - Target Quality Dataset

# %%
from src.raw_datset import raw_dataset

directory = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/RME01-2025Data"
new_directory = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Test_dataset"
local_files = raw_dataset(directory)
local_files.create_target_quality_dataset(new_directory)
# Out:
# 4it [00:42, 10.66s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 6
#       4 new_directory = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/Test_dataset"
#       5 local_files = raw_dataset(directory)
# ----> 6 local_files.create_target_quality_dataset(new_directory)
#
# File /data/Dataset_Compilation_and_Statistics/data_connections/src/raw_datset.py:728, in raw_dataset.create_target_quality_dataset(self, new_dataset_directory, move_mode)
#     724     bboxes.append(original_bbox)
#     725 plot_error_evaluator(image, bboxes, 0, properties)
# --> 728 star_quality = _select_star_quality()
#     729 target_quality = _select_target_quality()
#     731 if star_quality and target_quality:
#
# File /data/Dataset_Compilation_and_Statistics/data_connections/src/raw_datset.py:774, in _select_star_quality()
#     773 def _select_star_quality():
# --> 774     current_input = input("Enter Star Quality (0=worst, 2=best)")
#     775     if current_input:
#     776         return True
#
# File ~/miniconda3/envs/DatasetStatistics/lib/python3.12/site-packages/ipykernel/kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~/miniconda3/envs/DatasetStatistics/lib/python3.12/site-packages/ipykernel/kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
