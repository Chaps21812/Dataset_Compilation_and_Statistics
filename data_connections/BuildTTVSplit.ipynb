# %%
from src.coco_tools import build_annotations, generate_TTV_split, move_fits_to_train_test_split
from src.preprocess_functions import iqr_log

# %%
direc = "/data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/RME04-2025-Annotations/2025-06-01"
build_annotations(direc)
generate_TTV_split(direc)
move_fits_to_train_test_split(direc, iqr_log)
# Out:
# Deleted folder: /data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/RME04-2025-Annotations/2025-06-01/annotations
# Deleted folder: /data/Dataset_Compilation_and_Statistics/Sentinel_Datasets/RME04-2025-Annotations/2025-06-01/multiframe_annotations
# ...
# Building COCO Annotations:  49%|████▊     | 426/877 [00:21<00:22, 20.10it/s]/home/davidchaparro/miniconda3/envs/DatasetStatistics/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/davidchaparro/miniconda3/envs/DatasetStatistics/lib/python3.12/site-packages/numpy/_core/_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/davidchaparro/miniconda3/envs/DatasetStatistics/lib/python3.12/site-packages/numpy/_core/_methods.py:223: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# ...
